# %%
nama_kendaraan = input ('Nama Kendaraan?')
jenis_bensin = input ('Jenis Besin? ')
kota = input ('Kota yang di tuju?')

if jenis_bensin == 'Pertalite':
  harga = 10000
  jarak_tempuh = 12
elif jenis_bensin == 'Pertamax':
  harga = 14000
  jarak_tempuh = 13
elif jenis_bensin == 'Pertamax Turbo':
  harga = 17000
  jarak_tempuh = 13.5
else:
  print('Not Found')


if kota == 'Jakarta':
  jarak = 20
elif kota == 'Bekasi':
  jarak = 35.7
elif kota == 'Depok':
  jarak = 5
elif kota == 'Tanggerang':
  jarak = 99
elif kota == 'Bogor':
  jarak = 120.6
else:
  print('Not Found')

jarak_tempuh = jarak/jarak_tempuh
harga = jarak_tempuh*harga

print(nama_kendaraan, jenis_bensin, kota)
print(jarak_tempuh, harga)
# Out:
# Nama Kendaraan?Motor
# Jenis Besin? Pertamax
# Kota yang di tuju?Jakarta
# Motor Pertamax Jakarta
# 1.5384615384615385 21538.46153846154

# %%
nama_pembeli = input ('Masukkan Nama Pembeli?')
no_hp = input ('Masukan No Hp Pembeli? ')
menu = input ('Pesan Menu Apa? ')
pesanan = input ('Masukan Pesanan')
jumlah_pesanan = input ('Masukan Jumlah Pesanan')

if menu == 'Nasi Goreng':
  harga = 15000
elif menu == 'Mie Goreng':
  harga = 12000
elif menu == 'Ayam Geprek':
  harga = 18000
else:
  print('Not Found')

if menu == 'Aneka Jus':
  harga = 15000
elif menu == 'Soft Drink':
  harga = 10000
elif menu == 'Sweet Ice Tea':
  harga = 5000
else:
  print('Not Found')

print(nama_pembeli, no_hp, menu)
print(pesanan, jumlah_pesanan)
# Out:
# Masukkan Nama Pembeli?Afif
# Masukan No Hp Pembeli? 081364485205
# Pesan Menu Apa? Minuman
# Masukan PesananAneka Jus
# Masukan Jumlah Pesanan15000
# Not Found
# Not Found
# Afif 081364485205 Minuman
# Aneka Jus 15000
